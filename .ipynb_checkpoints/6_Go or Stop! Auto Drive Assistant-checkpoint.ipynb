# %% [markdown]
# # 아직 과제 진행중임! 제출 시각을 놓칠까봐 미리 제출하였습니다 ㅠㅠㅠㅠ

# %% [markdown]
# ## 이 노드의 루브릭
# ---
#
# 1. KITTI 데이터셋에 대한 분석이 체계적으로 진행되었다.
# : KITTI 데이터셋 구조와 내용을 파악하고 이를 토대로 필요한 데이터셋 가공을 정상 진행하였다.
#
#
# 2. RetinaNet 학습이 정상적으로 진행되어 Object Detection 결과의 시각화까지 진행되었다.
# : 바운딩 박스가 정확히 표시된 시각화된 이미지를 생성하였다.
#
#
# 3. 자율주행 Object Detection 테스트 시스템 적용 결과, 만족스러운 정확도 성능을 달성하였다.
# : 테스트 결과 90% 이상의 성능을 달성하였다.

# %% [markdown]
# ## 목차
# ----
#
# 1. 데이터셋 로드
#     - 필요한 라이브러리 임포트
#     - 데이터 배정
#     - 이미지 시각화하여 확인하기
#
# 2. 학습 모델 구성하기
# 3. 훈련하기
# 4. 시각화하기

# %% [markdown]
# ## 1. 데이터셋 로드
# ---

# %%
#필요한 라이브러리 임포트
import tensorflow as tf
from tensorflow import keras

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from tqdm import tqdm

import tensorflow_datasets as tfds

#이미지 시각화와 관련된 라이브러리
import copy
import cv2
from PIL import Image, ImageDraw

print('필요한 라이브러리 임포트 완료')
# Out:
# 필요한 라이브러리 임포트 완료

# %%
kitti_builder = tfds.builder("kitti")
kitti_builder.download_and_prepare()

# %%
print(kitti_builder.info.features)
# Out:
# FeaturesDict({
#     'image': Image(shape=(None, None, 3), dtype=tf.uint8),
#     'image/file_name': Text(shape=(), dtype=tf.string),
#     'objects': Sequence({
#         'alpha': tf.float32,
#         'bbox': BBoxFeature(shape=(4,), dtype=tf.float32),
#         'dimensions': Tensor(shape=(3,), dtype=tf.float32),
#         'location': Tensor(shape=(3,), dtype=tf.float32),
#         'occluded': ClassLabel(shape=(), dtype=tf.int64, num_classes=4),
#         'rotation_y': tf.float32,
#         'truncated': tf.float32,
#         'type': ClassLabel(shape=(), dtype=tf.int64, num_classes=8),
#     }),
# })

# %% [markdown]
# > - 위와 같은 feature를 가졌음을 알 수 있다.
# > - 또한, kitti_builder.info 로 확인했을 때, 다운로드된 데이터셋은 test-train-validation 순으로 저장되어 있다.

# %%
import os

#다운로드한 라이브러리 확인
dir_path = os.getenv('HOME')+'/GoingDeep/6_RetinaNet/kitti_images/'

if os.path.isdir(dir_path):
    files = os.listdir(direc_path)
    file_count = len(files)
    print('이미지 파일 갯수 : ', file_count)
# Out:
# 이미지 파일 갯수 :  7058

# %% [markdown]
# ![이미지 파일 설명](./PostingPic/datasplit.png)

# %% [markdown]
# - tensorflow_datasets의 설명대로, 총 7058(test 711 + train 6,374 + validation 423)개의 데이터셋이 존재함을 확인할 수 있다.

# %%
#directory 안의 파일들을 tfds.Split을 이용하여 test, train, validation set으로 나눠준다.    
#다운로드된 데이터의 수로 확인했을 때, 각각 0.1, 0.85, 0.5 만큼의 비중을 가진다.

test_data = kitti_builder.as_dataset(split=tfds.Split.TEST)
train_data = kitti_builder.as_dataset(split=tfds.Split.TRAIN)
vali_data = kitti_builder.as_dataset(split=tfds.Split.VALIDATION)

# %%
print('테스트 데이터 수 : ' , len(test_data))
print('학습 데이터 수 : ', len(train_data))
print('검증 데이터 수 : ', len(vali_data))
# Out:
# 테스트 데이터 수 :  711
# 학습 데이터 수 :  6347
# 검증 데이터 수 :  423

# %% [markdown]
# > - 목적했던 수 대로 잘 나누어져 있음을 확인할 수 있다.

# %%
data_info = kitti_builder.info

# %%
figure = tfds.show_examples(train_data, data_info)

# %% [markdown]
# ### 데이터셋의 바운딩 박스 확인하기
# ---
#
# 1. 다운로드한 데이터셋으로부터 하나의 이미지를 가져와, 이 이미지의 특성(바운딩 박스)을 확인해본다.
# 2. 바운딩 박스를 이미지 위에 시각화하여 나타낸다.

# %%
one_image = train_data.take(2)

# %%
for example in one_image:
    print("----설명하기----")
    #이 이미지가 가진 '키' 즉, 특성값들을 인쇄하여 확인한다.
    print(list(example.keys()))
    
    image = example["image"]
    filename = example["image/file_name"].numpy().decode('utf-8')
    objects = example["objects"]
    
print("----objects-----")
print(objects)

#위에서 배정한 image를 numpy로 변환 후, PIL이미지로 변환하여 나타낸다.
image = Image.fromarray(image.numpy())
image
# Out:
# ----설명하기----
# ['image', 'image/file_name', 'objects']
# ----설명하기----
# ['image', 'image/file_name', 'objects']
# ----objects-----
# {'alpha': <tf.Tensor: shape=(4,), dtype=float32, numpy=array([-1.58, -0.92,  0.39,  2.05], dtype=float32)>, 'bbox': <tf.Tensor: shape=(4, 4), dtype=float32, numpy=
# array([[0.48171124, 0.44008884, 0.5474599 , 0.46107432],
#        [0.4289305 , 0.36235055, 0.55342245, 0.44479805],
#        [0.3255615 , 0.        , 0.4909893 , 0.07074314],
#        [0.45467913, 0.2655008 , 0.5442781 , 0.3208966 ]], dtype=float32)>, 'dimensions': <tf.Tensor: shape=(4, 3), dtype=float32, numpy=
# array([[1.48, 1.56, 3.62],
#        [1.67, 1.64, 4.32],
#        [1.5 , 1.62, 3.88],
#        [1.68, 1.67, 4.29]], dtype=float32)>, 'location': <tf.Tensor: shape=(4, 3), dtype=float32, numpy=
# array([[ -2.76,   0.74,  45.39],
#        [ -3.88,   1.14,  28.08],
#        [-15.76,   1.76,  18.39],
# ...

# %%
#해당 이미지 위에 바운딩 박스를 그리기 위한 함수를 정의한다.
#위의 설명에서
#'bbox': <tf.Tensor: shape=(1, 4), dtype=float32, 
#     numpy=array([[0.40194666, 0.398438  , 0.5124533 , 0.4485185 ]], dtype=float32)
#부분을 참조해야 한다.

def visualize_bbox(input_image, object_bbox):
    
    #원본 이미지에 손상이 가지 않도록 깊은 복사를 한 후, 복사한 이미지를 그린다.
    input_image = copy.deepcopy(input_image)
    draw = ImageDraw.Draw(input_image)
    
    width = input_image.width
    height = input_image.height
    
    w_min = object_bbox[:, 1] * width
    w_max = object_bbox[:, 3] * width
    h_min = object_bbox[:, 0] * height
    h_max = object_bbox[:, 2] * height
    
    rects = np.stack([w_min, h_min, w_max, h_max], axis=1)
    
    for rec in rects:
        #xy – Two points to define the bounding box. 
        #Sequence of either [(x0, y0), (x1, y1)] or [x0, y0, x1, y1].
        draw.rectangle(rec, outline=(0,255,0), width=1)
    
    return input_image

# %%
visualize_bbox(image, objects['bbox'].numpy())
# Out:
# <PIL.Image.Image image mode=RGB size=1238x374 at 0x7FBB6C201FD0>

# %% [markdown]
# ## 2. 학습 모델 구성하기
# ---

# %% [markdown]
# - Keras 라이브러리로 구현된 RetinaNet을 가져와 훈련시킨다.
# - 훈련을 위해, 보유한 tensorflow_dataset의 KITTI 데이터셋 포맷을 csv로 변경한다.

# %% [markdown]
# > 이미지, 바운딩박스 위치, 클래스
#
# 의 형태로 csv 파일이 생성될 수 있도록 한다.

# %%
import os

#위에서 사용한 dir_path 응용
#dir_path = os.getenv('HOME')+'/GoingDeep/6_RetinaNet/kitti_images/'
data_dir = os.path.join(dir_path, 'data')
image_dir = os.path.join(dir_path, 'image')

train_csv_path = dir_path+ 'kitti_train.csv'

# %%
#데이터를 파싱하여 dataframe으로 변환하고,
#이를 csv 파일로 저장하는 함수 정의

def parsing_data(dataset, image_dir="kitti_images", total=0):
    
    if not os.path.exists(image_dir):
        os.mkdir(image_dir)
        
    type_class_map={
         0: "car",
        1: "car",
        2: "car",
        3: "person",
        4: "person",
        5: "person",
    }
    
    df = pd.DataFrame(columns=["img_path", "x1", "y1", "x2", "y2", "class_name"])
    
    for item in tqdm(dataset, total=total):
        #파일 이름 산출
        file_name = item["image/file_name"].numpy().decode('utf-8')
        
        #바운딩 박스의 좌표 산출
        image_path = os.path.join(image_dir, file_name)
        image = Image.fromarray(item['image'].numpy())
        image.save(image_path)
        
        object_bbox = item['objects']['bbox']
        object_type = item['objects']['type'].numpy()
        
        width, height = image.size
        
        #0~1사이로 노말라이즈되었던 좌표를 실제 사이즈에 기반한 픽셀 좌표로 변환
        x_min = object_bbox[:,1] * width
        x_max = object_bbox[:,3] * width
        y_min = height - object_bbox[:,2] * height
        y_max = height - object_bbox[:,0] * height
        
        rects = np.stack([x_min, y_min, x_max, y_max], axis=1).astype(np.int)
        for i, _rect in enumerate(rects):
            _type = object_type[i]
            if _type not in type_class_map.keys():
                continue
            df = df.append({
                "img_path": image_path,
                "x1": _rect[0],
                "y1": _rect[1],
                "x2": _rect[2],
                "y2": _rect[3],
                "class_name": type_class_map[_type]
            }, ignore_index=True)
            break
            
        return df

# %%
train_df = parsing_data(train_data, image_dir, total=data_info.splits['train'].num_examples)
train_df.to_csv(train_csv_path, sep=',', index=False, header=False)

# %% [markdown]
# > - 사실 과제를 제출하기 전 미리 csv파일을 만들어놨었으므로 그걸 쓰기로 한다..

# %% [markdown]
# ### 클래스 매핑
# ---
#
# - 모델에게 숫자로 클래스를 알려주기 위해, '클래스', '클래스 숫자' 로 이루어진 파일을 별도로 만들기로 한다.

# %%
class_text_path = data_dir + '/classes.txt'

# %%
def save_class_format(path=class_text_path):
    class_type_map ={
        "car" : 0,
        "person" : 1
        
    }
    
    with open(path, mode='w', encoding='utf-8') as f:
        
        for i, v in class_type_map:
            f.write(f"{i},{v}\n")

# %% [markdown]
# ## 3. 훈련하기
# ---

# %%
# !cd ~/GoingDeep/6_RetinaNet && python keras-retinanet/keras_retinanet/bin/train.py --gpu 0 --multiprocessing --workers 4 --batch-size 16 --epochs 25 --steps 150 csv data/kitti_train.csv data/classes.txt
# Out:
# 2021-04-27 22:30:02.027334: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-04-27 22:30:02.027357: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2021-04-27 22:30:03.314406: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-27 22:30:03.314971: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-04-27 22:30:03.339976: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...
